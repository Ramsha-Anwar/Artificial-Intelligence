# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Path = 'drive/My Drive/datasets'

# %%
import pandas as pd
df = pd.read_csv(Path+'/Cleaned_Dataset.csv')

# %%
df.head(10)
# Out:
#                               Company  Company Score  \
# 0                          Razorpoint            3.4
# 1                       tower Hamlets            3.7
# 2                                  TW            4.0
# 3                       NatWest Group            4.6
# 4                               iwoca            3.9
# 5                             Spotify            3.8
# 6  LSEG (London Stock Exchange Group)            4.1
# 7                                CRED            4.1
# 8                        MLN Security            3.2
# 9                  PlayStation Global            4.0
#
#                                       Job Title  Date    Salary  \
# 0                         Junior Data Scientist   3.0   35000.0
# 1  Assistant Data Scientist (Graduate) | R-2375   5.0   64480.0
# 2                                Data Scientist  31.0   57500.0
# 3                                Data Scientist   2.0   47500.0
# 4                          Data Scientist - Ops   7.0   75000.0
# 5       Data Scientist, Programming & Editorial  41.0  124000.0
# 6                                Data Scientist  20.0   80000.0
# 7                                Data Scientist  26.0   36000.0
# 8                         Junior Data Scientist  33.0   59500.0
# 9                                Data Scientist  11.0   34000.0
#
#                                               Skills Estimation Type  Remote  \
# 0  Data mining, Big data, R, Data analysis skills...   Employer est.  Onsite
# 1                         R, SQL, JavaScript, Python   Employer est.  Onsite
# 2                   SQL, Maths, Data science, Python   Employer est.  Onsite
# 3  Software deployment, Data analysis skills, Sta...   Glasdoor est.  Onsite
# 4              MATLAB, R, Maths, C, Machine learning   Employer est.  Onsite
# 5  Data analysis skills, Tableau, SQL, Data scien...   Employer est.  Onsite
# 6       Jira, MATLAB, Power BI, Operating systems, R   Glasdoor est.  Onsite
# 7  Power BI, Data mining, R, Data analysis skills...   Employer est.  Remote
# 8               TensorFlow, SAS, Big data, Java, AWS   Glasdoor est.  Onsite
# 9  Tableau, SQL, Data management, Data science, C...   Employer est.  Onsite
#
#          City   Country
# 0  Manchester   England
# 1      London   England
# 2  Nottingham   England
# 3   Edinburgh  Scotland
# 4      London   England
# 5      London   England
# 6      London   England
# 7         NaN       NaN
# 8      London   England
# 9      London   England

# %%
print("\nBasic information about the dataset:")
print(df.info())
# Out:
# Basic information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 635 entries, 0 to 634
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Company          635 non-null    object
#  1   Company Score    635 non-null    float64
#  2   Job Title        635 non-null    object
#  3   Date             635 non-null    float64
#  4   Salary           635 non-null    float64
#  5   Skills           635 non-null    object
#  6   Estimation Type  635 non-null    object
#  7   Remote           635 non-null    object
#  8   City             581 non-null    object
#  9   Country          581 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 49.7+ KB
# None

# %%
print("\nStatistical summary of the dataset:")
print(df.describe())
# Out:
# Statistical summary of the dataset:
#        Company Score        Date         Salary
# count     635.000000  635.000000     635.000000
# mean        3.850866   27.601575   65487.181102
# std         0.465001   13.318958   22964.437740
# min         1.700000    2.000000   24500.000000
# 25%         3.600000   14.000000   49250.000000
# 50%         3.900000   32.000000   63000.000000
# 75%         4.100000   39.000000   76250.000000
# max         5.000000   44.000000  200000.000000

# %%
print("\nNumber of missing values in each column:")
print(df.isnull().sum())
# Out:
# Number of missing values in each column:
# Company             0
# Company Score       0
# Job Title           0
# Date                0
# Salary              0
# Skills              0
# Estimation Type     0
# Remote              0
# City               54
# Country            54
# dtype: int64

# %%
print("\nNumber of unique values in each column:")
print(df.nunique())
# Out:
# Number of unique values in each column:
# Company            414
# Company Score       27
# Job Title          464
# Date                39
# Salary             164
# Skills             573
# Estimation Type      2
# Remote               2
# City                77
# Country              4
# dtype: int64

# %%
print("\nNumber of rows and columns in the dataset:")
print(df.shape)
# Out:
# Number of rows and columns in the dataset:
# (635, 10)

# %%
print("\nNumber of duplicate rows in the dataset:")
print(df.duplicated().sum())
# Out:
# Number of duplicate rows in the dataset:
# 0

# %%
print("\nNumber of rows with missing values:")
print(df.isnull().any(axis=1).sum())
# Out:
# Number of rows with missing values:
# 54
